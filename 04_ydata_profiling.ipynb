# %% [markdown]
# ## Automatic EDA using `ydata_profiling`

# %%
# Import libararies 

import pandas as pd 
import seaborn as sns 

import data_profiling as yd

# %%
# Import data from seaborn 

# df = sns.load_dataset('titanic')

# %%
# Ydata Profiling report 
# profile = yd.ProfileReport(df)

# profile.to_file(output_file='./outputs/yadata_titanic.html')

# %% [markdown]
# # Do it on our Pak Population Dataset

# %%
df_pop = pd.read_csv('./data/data.csv')

# %%
profile = yd.ProfileReport(df_pop)

profile.to_file(output_file='./outputs/yadata_pak_population.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  7.26it/s]
